# %%
pip install striprtf
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from striprtf.striprtf import rtf_to_text
import numpy as np

# %%
with open("Russell Brand Script.rtf") as infile:
    content = infile.read()
    text = rtf_to_text(content)
print(text)
# Out:
# 00:00
# merry christmas it's our christmas video
# 00:03
# to you i already regret this hat but if
# 00:05
# we got some fantastic content for you a
# 00:07
# look at the most joyous and wonderful
# 00:09
# aspects have a very merry year ho ho ho
# 00:16
# hello there you four and a half million
# 00:18
# christmas miracles as far as i'm
# 00:20
# concerned each and every one of you was
# 00:22
# born that day under a star worthy of
# 00:26
# love no matter what you're in where
# 00:28
# you're from what you believe in i love
# 00:31
# you christmas time let's think about it
# 00:32
# just for a little moment a time of
# 00:35
# togetherness unity recognizing that it's
# 00:38
# a solstice a high point in winter a time
# 00:40
# where
# 00:41
# new beginnings are underneath the earth
# 00:44
# underneath the soil amidst the frost new
# 00:47
# things are beginning changes are
# 00:50
# occurring if you're in my country
# 00:52
# england britain uk the queen will do a
# 00:55
# ...

# %%
count = 0
for line in text:
    print(line)
        #count+=1
        #if count % 2 == 0: #this is the remainder operator
            #print(line)
# Out:
# 0
# 0
# :
# 0
# 0
#
#
# m
# e
# r
# r
# y
#
# c
# h
# r
# i
# s
# t
# m
# a
# s
#
# i
# t
# '
# s
#
# o
# u
# r
#
# c
# h
# r
# i
# s
# t
# m
# a
# s
#
# v
# i
# d
# e
# o
#
#
# 0
# 0
# :
# 0
# 3
#
#
# t
# o
#
# y
# o
# u
#
# i
#
# a
# l
# r
# e
# a
# d
# y
#
# r
# e
# g
# r
# e
# t
#
# t
# h
# i
# s
#
# h
# a
# t
#
# b
# u
# t
#
# i
# f
#
#
# 0
# 0
# :
# 0
# 5
#
#
# w
# e
#
# g
# o
# t
#
# s
# o
# m
# e
#
# f
# a
# n
# t
# a
# s
# t
# i
# c
#
# c
# o
# n
# t
# e
# n
# t
#
# f
# o
# r
#
# y
# o
# u
#
# a
#
#
# 0
# 0
# :
# 0
# 7
#
#
# l
# o
# o
# k
#
# a
# t
#
# t
# h
# e
#
# m
# o
# s
# t
#
# j
# o
# y
# o
# u
# s
#
# a
# n
# d
#
# w
# o
# n
# d
# e
# r
# f
# u
# l
#
#
# 0
# 0
# :
# 0
# 9
#
#
# a
# s
# p
# e
# c
# t
# s
#
# h
# a
# v
# e
#
# a
#
# v
# e
# r
# y
#
# m
# e
# r
# r
# y
#
# y
# e
# a
# r
#
# h
# o
#
# h
# o
#
# h
# o
#
#
# 0
# 0
# :
# 1
# 6
#
#
# h
# e
# l
# l
# o
#
# t
# h
# e
# r
# e
#
# y
# o
# u
#
# f
# o
# u
# r
#
# a
# n
# d
#
# a
#
# h
# a
# l
# f
#
# m
# i
# l
# ...

# %%
for count, line in enumerate(text, start=1):
        if count % 2 == 0:
            print(line)
# Out:
# 0
# 0
#
#
# e
# r
#
# h
# i
# t
# a
#
# t
# s
# o
# r
# c
# r
# s
# m
# s
# v
# d
# o
# 0
# :
# 3
# t
#
# o
#
#
# l
# e
# d
#
# e
# r
# t
# t
# i
#
# a
#
# u
#
# f
# 0
# :
# 5
# w
#
# o
#
# o
# e
# f
# n
# a
# t
# c
# c
# n
# e
# t
# f
# r
# y
# u
# a
# 0
# :
# 7
# l
# o
#
# t
# t
# e
# m
# s
#
# o
# o
# s
# a
# d
# w
# n
# e
# f
# l
# 0
# :
# 9
# a
# p
# c
# s
# h
# v
#
#
# e
# y
# m
# r
# y
# y
# a
#
# o
# h
#
# o
# 0
# :
# 6
# h
# l
# o
# t
# e
# e
# y
# u
# f
# u
#
# n
#
#
# a
# f
# m
# l
# i
# n
# 0
# :
# 8
# c
# r
# s
# m
# s
# m
# r
# c
# e
#
# s
# f
# r
# a
#
# '
#
#
# 0
# 2
#
#
# o
# c
# r
# e
#
# a
# h
# a
# d
# e
# e
# y
# o
# e
# o
#
# o
#
# a
#
#
# 0
# 2
#
#
# o
# n
# t
# a
#
# a
#
# n
# e
#
#
# t
# r
# w
# r
# h
#
# f
# 0
# :
# 6
# l
# v
#
# o
# m
# t
# e
#
# h
# t
# y
# u
# r
#
# n
# w
# e
# e
# 0
# :
# 8
# y
# u
# r
#
# r
# m
# w
# a
#
# o
#
# e
# i
# v
#
# n
# i
# l
# v
#
#
# 0
# 3
#
#
# o
#
# h
# i
# t
# a
#
# i
# e
# l
# t
# s
# t
# i
# k
# a
# o
# t
# i
#
#
# 0
# ...

# %%
f = open("Russell Brand Script.rtf", 'r')
cont=f.readlines()
txt=rtf_to_text(cont)
for line in txt:
    n=txt.readlines()
    print(n)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-81efef82a07e> in <module>
#       1 f = open("Russell Brand Script.rtf", 'r')
#       2 cont=f.readlines()
# ----> 3 txt=rtf_to_text(cont)
#       4 for line in txt:
#       5     n=txt.readlines()
#
# /Applications/anaconda3/lib/python3.8/site-packages/striprtf/striprtf.py in rtf_to_text(text, errors)
#     104     encoding = 'utf8'
#     105
# --> 106     for match in PATTERN.finditer(text):
#     107         word, arg, _hex, char, brace, tchar = match.groups()
#     108         if brace:
#
# TypeError: expected string or bytes-like object
